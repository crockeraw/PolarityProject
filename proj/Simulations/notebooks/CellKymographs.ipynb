# %% [markdown]
# ### Plot as kymograph
#
# Images were segmented manually in imageJ

# %%
using CSV
using DataFrames
using Plots

# %%
Sc = CSV.read("/home/dinosaur/Lab/Images-Ap/2024_02_28-Ste20GFP-movies/KymoResults/Sc-im16-cell1.csv", DataFrame);

# %%
Plots.heatmap(Matrix(Sc)[:, 4:end], clim=(100,250))

# %%
Sc2 = CSV.read("/home/dinosaur/Lab/Images-Ap/2024_02_28-Ste20GFP-movies/KymoResults/Ap-im21-cell1.csv", DataFrame);

# %%
Plots.heatmap(Matrix(Sc2)[:, 4:end], clim=(100,250))

# %%
Sc2 = CSV.read("/home/dinosaur/Lab/Images-Ap/2024_02_28-Ste20GFP-movies/KymoResults/Sc-im16-cell7.csv", DataFrame);

# %%
Plots.heatmap(Matrix(Sc2)[:, 4:end], clim=(100,250))
