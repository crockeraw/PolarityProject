# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

fig, ax = plt.subplots(figsize=(6, 2))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)
# ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.text(-60,0,s="nt", va="center")
#ApBem1
seq_len = 583
ax.plot(np.arange(seq_len), np.ones(seq_len))
plt.text(-100,1, s="ApBem1", va="center")
ax.set_ylim(0,3)
feat = "SH3"
start=33
stop=91
ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start), linewidth=12)
ax.text((stop+start)/2, 1, s=feat, ha="center", va="center")
feat = "SH3"
start=140
stop=196
ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start), linewidth=12)
ax.text((stop+start)/2, 1, s=feat, ha="center", va="center")
feat = "PX"
start=292
stop=400
ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start), linewidth=12)
ax.text((stop+start)/2, 1, s=feat, ha="center", va="center")
# feat = "PB1*"
# start=490
# stop=580
# ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start), linewidth=12)
# ax.text((stop+start)/2, 1, s=feat, ha="center", va="center")
#ScBem1
ax.set_prop_cycle(None)
seq_len = 551
ax.plot(np.arange(seq_len), np.ones(seq_len)*2)
plt.text(-100,2, s="ScBem1", va="center")
feat = "SH3"
start=75
stop=127
ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*2, linewidth=12)
ax.text((stop+start)/2, 2, s=feat, ha="center", va="center")
feat = "SH3"
start=158
stop=214
ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*2, linewidth=12)
ax.text((stop+start)/2, 2, s=feat, ha="center", va="center")
feat = "PX"
start=283
stop=400
ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*2, linewidth=12)
ax.text((stop+start)/2, 2, s=feat, ha="center", va="center")
feat = "PB1"
start=477
stop=549
ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*2, linewidth=12)
ax.text((stop+start)/2, 2, s=feat, ha="center", va="center")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Text(513.0, 2, 'PB1')

# %%
import pandas as pd
#header=["gene", "start", "stop", "domain", "misc", "junk"]
df = pd.read_csv("../annotations/ApBem1_Features.BED", sep="\t", header=None)

cset3 = plt.cm.Set2.colors + plt.cm.Set3.colors + plt.cm.Set1.colors

# %%
fig, ax = plt.subplots(figsize=(7, 1))
ax.set_ylim(0,3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)

seq_name = ["ApBem1","ScBem1"]
seq_len = [583, 558]

for n, name in enumerate(seq_name):
    df = pd.read_csv(f"../annotations/{name}_Features.BED", sep="\t", header=None)
    # ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    ax.plot(np.arange(seq_len[n]), np.ones(seq_len[n])*(n+1), color=["C0","C3"][n], linewidth=5)
    ax.text(-200,0,s="amnio acid", va="center", fontsize=8)
    plt.text(-200,n+1, s=name, va="center", fontsize=8)
    # Add box and label for each feature on sequence
    color_list = [[0,0,2,3],[0,0,2,3]]
    for index, row in df.iterrows():
        feat = row[3]
        start= row[1]
        stop= row[2]
        ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*(n+1), linewidth=15, color=cset3[color_list[n][index]])
        ax.text((stop+start)/2, n+1, s=feat, ha="center", va="center", fontsize=8)
        ax.set_xlim(0,1050)
plt.savefig("feat_Bem1.svg",transparent=True)

# %%
fig, ax = plt.subplots(figsize=(7, 1))
ax.set_ylim(0,3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)

seq_name = ["ApCdc24","ScCdc24"]
seq_len = [1009, 866]

for n, name in enumerate(seq_name):
    ax.set_prop_cycle("color", plt.cm.Set2.colors)
    df = pd.read_csv(f"../annotations/{name}_Features.BED", sep="\t", header=None)
    # ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    ax.plot(np.arange(seq_len[n]), np.ones(seq_len[n])*(n+1), color=["C0","C3"][n], linewidth=5)
    ax.text(-200,0,s="amnio acid", va="center", fontsize=8)
    plt.text(-200,n+1, s=name, va="center", fontsize=8)
    color_list = [[4,5,6,3,7],[4,5,6,3]]
    for index, row in df.iterrows():
        feat = row[3]
        start= row[1]
        stop= row[2]
        ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*(n+1), linewidth=15, color=cset3[color_list[n][index]])
        ax.text((stop+start)/2, n+1, s=feat, ha="center", va="center", fontsize=8)
        ax.set_xlim(0,1050)
plt.savefig("feat_Cdc24.svg",transparent=True)

# %%
fig, ax = plt.subplots(figsize=(7, 2))
ax.set_ylim(0,5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)

seq_name = ["ApPak2","ApPak1","ScCla4","ScSte20"]
seq_len = [828, 826, 854, 952]

matplotlib.rc('xtick', labelsize=8)

for n, name in enumerate(seq_name):
    ax.set_prop_cycle("color", plt.cm.Set2.colors)
    df = pd.read_csv(f"../annotations/{name}_Features.BED", sep="\t", header=None)
    # ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    ax.plot(np.arange(seq_len[n]), np.ones(seq_len[n])*(n+1), color=["C0","C0","C3","C3"][n], linewidth=5)
    ax.text(-200,0,s="amnio acid", va="center", fontsize=8)
    plt.text(-200,n+1, s=name, va="center", fontsize=8)
    color_list = [[15,11],[6,15,11],[6,15,11],[15,11]]
    for index, row in df.iterrows():
        feat = row[3]
        start= row[1]
        stop= row[2]
        ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*(n+1), linewidth=15, color=cset3[color_list[n][index]])
        ax.text((stop+start)/2, n+1, s=feat, ha="center", va="center", fontsize=8)
        ax.set_xlim(0,1050)
plt.savefig("feat_Pak1.svg",transparent=True)

# %%
fig, ax = plt.subplots(figsize=(16, 2))
ax.set_ylim(0,3)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(False)

seq_name = ["ApCdc42","ScCdc42"]
seq_len = [250, 250]

for n, name in enumerate(seq_name):
    ax.set_prop_cycle("color", plt.cm.Set2.colors)
    df = pd.read_csv(f"../annotations/{name}_siteFeatures.BED", sep="\t", header=None)
    # ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    ax.plot(np.arange(seq_len[n]), np.ones(seq_len[n])*(n+1), color=["C0","C3"][n], linewidth=5)
    ax.text(-100,0,s="amnio acid", va="center")
    plt.text(-100,n+1, s=name, va="center", fontsize=16)
    # Add box and label for each feature on sequence
    color_list = [[8,11,6,1,1,1],[8,11,6,1,1,1]]
    for index, row in df.iterrows():
        feat = row[3]
        start= row[1]
        stop= row[2]
        ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*(n+1), linewidth=25, color=cset3[color_list[n][index]])
        #ax.text((stop+start)/2, n+1, s=feat, ha="center", va="center", fontsize=16)
        ax.set_xlim(0,250)
#plt.savefig("sitefeat_Cdc42.png")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 25
#      23 start= row[1]
#      24 stop= row[2]
# ---> 25 ax.plot(np.arange(start=start, stop=stop), np.ones(stop-start)*(n+1), linewidth=25, color=cset3[color_list[n][index]])
#      26 #ax.text((stop+start)/2, n+1, s=feat, ha="center", va="center", fontsize=16)
#      27 ax.set_xlim(0,250)
#
# IndexError: list index out of range
